# %%
# Q.1-->

import pandas as pd
print(pd.__version__)
# Out:
# 1.0.5

# %%
# Q.2 -->

import numpy as np
arr = np.array([100,200,300,'Aashish','Mandal',400,500,600,700])
series = pd.Series(arr)
print(series)
# Out:
# 0        100
# 1        200
# 2        300
# 3    Aashish
# 4     Mandal
# 5        400
# 6        500
# 7        600
# 8        700
# dtype: object

# %%
# Q. 3-->

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data)
df = df.rename_axis('S.No.').reset_index()
print( df.to_string(index=False))
# Out:
#  S.No.       name  score  attempts qualify
#      0  Anastasia   12.5         1     yes
#      1       Dima    9.0         3      no
#      2  Katherine   16.5         2     yes
#      3      James    NaN         3      no
#      4      Emily    9.0         2      no
#      5    Michael   20.0         3     yes
#      6    Matthew   14.5         1     yes
#      7      Laura    NaN         1      no
#      8      Kevin    8.0         2      no
#      9      Jonas   19.0         1     yes

# %%
# Q.4 -->

import seaborn as sns
print(sns.get_dataset_names())

df = sns.load_dataset('mpg')
df.style.hide_index()
# Out:
# E:\python\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file E:\python\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']
# <style  type="text/css" >
# </style><table id="T_693227f1_2769_11eb_9d05_3065ec9fecc6" ><thead>    <tr>        <th class="col_heading level0 col0" >mpg</th>        <th class="col_heading level0 col1" >cylinders</th>        <th class="col_heading level0 col2" >displacement</th>        <th class="col_heading level0 col3" >horsepower</th>        <th class="col_heading level0 col4" >weight</th>        <th class="col_heading level0 col5" >acceleration</th>        <th class="col_heading level0 col6" >model_year</th>        <th class="col_heading level0 col7" >origin</th>        <th class="col_heading level0 col8" >name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col0" class="data row0 col0" >18.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col1" class="data row0 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col2" class="data row0 col2" >307.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col3" class="data row0 col3" >130.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col4" class="data row0 col4" >3504</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col5" class="data row0 col5" >12.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col6" class="data row0 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col7" class="data row0 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row0_col8" class="data row0 col8" >chevrolet chevelle malibu</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col0" class="data row1 col0" >15.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col1" class="data row1 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col2" class="data row1 col2" >350.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col3" class="data row1 col3" >165.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col4" class="data row1 col4" >3693</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col5" class="data row1 col5" >11.500000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col6" class="data row1 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col7" class="data row1 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row1_col8" class="data row1 col8" >buick skylark 320</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col0" class="data row2 col0" >18.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col2" class="data row2 col2" >318.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col3" class="data row2 col3" >150.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col4" class="data row2 col4" >3436</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col5" class="data row2 col5" >11.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col6" class="data row2 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col7" class="data row2 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row2_col8" class="data row2 col8" >plymouth satellite</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col0" class="data row3 col0" >16.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col1" class="data row3 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col2" class="data row3 col2" >304.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col3" class="data row3 col3" >150.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col4" class="data row3 col4" >3433</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col5" class="data row3 col5" >12.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col6" class="data row3 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col7" class="data row3 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row3_col8" class="data row3 col8" >amc rebel sst</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col0" class="data row4 col0" >17.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col1" class="data row4 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col2" class="data row4 col2" >302.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col3" class="data row4 col3" >140.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col4" class="data row4 col4" >3449</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col5" class="data row4 col5" >10.500000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col6" class="data row4 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col7" class="data row4 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row4_col8" class="data row4 col8" >ford torino</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col0" class="data row5 col0" >15.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col1" class="data row5 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col2" class="data row5 col2" >429.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col3" class="data row5 col3" >198.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col4" class="data row5 col4" >4341</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col5" class="data row5 col5" >10.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col6" class="data row5 col6" >70</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col7" class="data row5 col7" >usa</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row5_col8" class="data row5 col8" >ford galaxie 500</td>
#             </tr>
#             <tr>
#                                 <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col0" class="data row6 col0" >14.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col1" class="data row6 col1" >8</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col2" class="data row6 col2" >454.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col3" class="data row6 col3" >220.000000</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col4" class="data row6 col4" >4354</td>
#                         <td id="T_693227f1_2769_11eb_9d05_3065ec9fecc6row6_col5" class="data r

# %%
# Q.5 -->

df['origin']
# Out:
# 0         usa
# 1         usa
# 2         usa
# 3         usa
# 4         usa
#         ...
# 393       usa
# 394    europe
# 395       usa
# 396       usa
# 397       usa
# Name: origin, Length: 398, dtype: object

# %%
# Q.6 -->

df = sns.load_dataset('mpg')
(df[df['origin'] == 'usa'])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# 1            70    usa          buick skylark 320
# 2            70    usa         plymouth satellite
# 3            70    usa              amc rebel sst
# 4            70    usa                ford torino
# ..          ...    ...                        ...
# 392          82    usa           chevrolet camaro
# 393          82    usa            ford mustang gl
# 395          82    usa              dodge rampage
# 396          82    usa                ford ranger
# 397          82    usa                 chevy s-10
#
# [249 rows x 9 columns]
